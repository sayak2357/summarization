# %%
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import operator
import re
import glob

# %%
for i in range(79,100):
    n1 =str("output/")+str("P")+str(i)+str("*")+str("emails*")
    tp=0
    avgeml=0
    for name in glob.glob(n1):
        print(name)
        tp+=1
        t=open(name,'r')
        for j in t:
            print(j)
# Out:
# output\P79-1001_emails.xml
# output\P79-1002_emails.xml
# output\P79-1003_emails.xml
# output\P79-1004_emails.xml
# output\P79-1005_emails.xml
# output\P79-1006_emails.xml
# output\P79-1007_emails.xml
# output\P79-1008_emails.xml
# output\P79-1009_emails.xml
# output\P79-1010_emails.xml
# output\P79-1011_emails.xml
# output\P79-1012_emails.xml
# output\P79-1013_emails.xml
# output\P79-1014_emails.xml
# output\P79-1015_emails.xml
# output\P79-1016_emails.xml
# output\P79-1017_emails.xml
# output\P79-1018_emails.xml
# output\P79-1019_emails.xml
# output\P79-1020_emails.xml
# output\P79-1021_emails.xml
# output\P79-1022_emails.xml
# output\P79-1023_emails.xml
# output\P79-1024_emails.xml
# output\P79-1025_emails.xml
# output\P79-1026_emails.xml
# output\P79-1027_emails.xml
# output\P79-1028_emails.xml
# output\P80-1001_emails.xml
# output\P80-1002_emails.xml
# output\P80-1003_emails.xml
# output\P80-1004_emails.xml
# output\P80-1005_emails.xml
# output\P80-1006_emails.xml
# ...
