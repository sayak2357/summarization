# %%
import requests
r= requests.get('https://aclanthology.coli.uni-saarland.de/events/naacl-2003')

# %%
#print 100 characters
#print(r.text)

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all('p')

# %%
print(len(results))
# Out:
# 119

# %%
#file = open("acl15.txt","w")

# %%
for i in range(1,38):
    x=1000+i
    fl='<Paper id ='+"\"N03-"+str(x)+"\">"
    
    paper=results[i].find('strong').text
    sl = "<title>" +str(paper)+"</title>"
    tl="<Venue> ACL </venue>"
    ttl="<type>long</type>"
    ltl="<Year>2011</Year>"
    ll= "</Paper>"
    ao="<Authors>"
    ac="</Authors>"
    aao="<Author>"
    aac="</Author>"
    
    try:
        print(fl)
        #file.write(fl+'\n')
        print(sl)
        #file.write(sl+'\n')
        print(tl)
        #file.write(tl+'\n')
        print(ao)
        #file.write(ao+'\n')
    except:
        continue
    
    
    for j in range(4,20):
        try:
            y=results[i].find_all('a')[j].text
            d=y.split(" ")
            print(aao)
            #file.write(aao+'\n')
            z1="<FirstName>"+d[0]+"</FirstName>"
            z2="<SecondName>"+d[1]+"</SecondName>"
            print(z1)
            #file.write(z1+'\n')
            print(z2)
            #file.write(z2+'\n')
            print(aac)
            #file.write(aac+'\n')
        except  :
            continue
    
    
    
    print(ac)
    #file.write(ac+'\n')
    print(ttl)
    #file.write(ttl+'\n')
    print(ltl)
    #file.write(ltl+'\n')
    print(ll)
    #file.write(ll+'\n')
    print('\n\n\n')
    #file.write('\n\n')

file.close()
# Out:
# <Paper id ="N03-1001">
# <title>Effective Utterance Classification with Unsupervised Phonotactic Models</title>
# <Venue> ACL </venue>
# <Authors>
# <Author>
# <FirstName>Hiyan</FirstName>
# <SecondName>Alshawi</SecondName>
# </Author>
# </Authors>
# <type>long</type>
# <Year>2011</Year>
# </Paper>
#
#
#
#
# <Paper id ="N03-1002">
# <title>Japanese Named Entity Extraction with Redundant Morphological Analysis</title>
# <Venue> ACL </venue>
# <Authors>
# <Author>
# <FirstName>Masayuki</FirstName>
# <SecondName>Asahara</SecondName>
# </Author>
# <Author>
# <FirstName>Yuji</FirstName>
# <SecondName>Matsumoto</SecondName>
# </Author>
# </Authors>
# <type>long</type>
# <Year>2011</Year>
# </Paper>
#
#
#
#
# <Paper id ="N03-1003">
# <title>Learning to Paraphrase: An Unsupervised Approach Using Multiple-Sequence Alignment</title>
# <Venue> ACL </venue>
# <Authors>
# <Author>
# <FirstName>Regina</FirstName>
# <SecondName>Barzilay</SecondName>
# </Author>
# <Author>
# ...

# %%
#file2 = open("acl15.txt","w")

# %%
for i in range(39,77):
    x=2000+i-38
    fl='<Paper id ='+"\"N03-"+str(x)+"\">"
    
    paper=results[i].find('strong').text
    sl = "<title>" +str(paper)+"</title>"
    tl="<Venue> ACL </venue>"
    ttl="<type>short</type>"
    ltl="<Year>2011</Year>"
    ll= "</Paper>"
    ao="<Authors>"
    ac="</Authors>"
    aao="<Author>"
    aac="</Author>"
    try:
        print(fl)
        #file2.write(fl+'\n')
        print(sl)
        #file2.write(sl+'\n')
        print(tl)
        #file2.write(tl+'\n')
        print(ao)
        #file2.write(ao+'\n')
    except:
        continue
    
    
    for j in range(4,20):
        try:
            y=results[i].find_all('a')[j].text
            d=y.split(" ")
            print(aao)
            #file2.write(aao+'\n')
            z1="<FirstName>"+d[0]+"</FirstName>"
            z2="<SecondName>"+d[1]+"</SecondName>"
            print(z1)
            #file2.write(z1+'\n')
            print(z2)
            #file2.write(z2+'\n')
            print(aac)
            #file2.write(aac+'\n')
        except  :
            continue
    
    
    
    print(ac)
    #file2.write(ac+'\n')
    print(ttl)
    #file2.write(ttl+'\n')
    print(ltl)
    #file2.write(ltl+'\n')
    print(ll)
    #file2.write(ll+'\n')
    print('\n\n\n')
    #file2.write('\n\n')
    
file2.close()
# Out:
# <Paper id ="N03-2001">
# <title>Automating XML markup of text documents</title>
# <Venue> ACL </venue>
# <Authors>
# <Author>
# <FirstName>Shazia</FirstName>
# <SecondName>Akhtar</SecondName>
# </Author>
# <Author>
# <FirstName>Ronan</FirstName>
# <SecondName>G.</SecondName>
# </Author>
# <Author>
# <FirstName>John</FirstName>
# <SecondName>Dunnion</SecondName>
# </Author>
# </Authors>
# <type>short</type>
# <Year>2011</Year>
# </Paper>
#
#
#
#
# <Paper id ="N03-2002">
# <title>Factored Language Models and Generalized Parallel Backoff</title>
# <Venue> ACL </venue>
# <Authors>
# <Author>
# <FirstName>Jeff</FirstName>
# <SecondName>A.</SecondName>
# </Author>
# <Author>
# <FirstName>Katrin</FirstName>
# <SecondName>Kirchhoff</SecondName>
# </Author>
# </Authors>
# <type>short</type>
# <Year>2011</Year>
# </Paper>
#
#
#
#
# <Paper id ="N03-2003">
# <title>Getting More Mileage from Web Text Sources for Conversational Speech Language Modeling using Class-Dependent Mixtures</title>
# ...

# %%
file2.close()
