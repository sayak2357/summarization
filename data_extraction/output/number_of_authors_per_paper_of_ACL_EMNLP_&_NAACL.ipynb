# %%
from bs4 import BeautifulSoup

# %%
n1='acl/acl17.txt'
f1=open(n1,'r')
soup1=BeautifulSoup(f1,'html.parser')
result1=soup1.find_all('paper')
result2=result1[1].find_all('author')

# %%
x=[]
y=[]
for i in range(0,len(result1)):
    x.append(i)
    z=len(result1[i].find_all('author'))
    y.append(z)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = x
y_pos = np.arange(len(objects))
performance = y
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Authors')
plt.title('Number of Authors per pape of ACL 2017')
plt.xlabel("paper number")
 
plt.show()

# %%
n2='acl/acl79.txt'
f2=open(n2,'r')
soup2=BeautifulSoup(f2,'html.parser')
result1=soup2.find_all('paper')
result2=result1[1].find_all('author')

# %%
m=[]
n=[]
for i in range(0,len(result1)):
    m.append(i)
    z=len(result1[i].find_all('author'))
    n.append(z)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = m
y_pos = np.arange(len(objects))
performance = n
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Authors')
plt.title('Numbers of Authors per paper of ACL 1979')
plt.xlabel("paper number")
 
plt.show()

# %%
n3='emnlp/emnlp96.txt'
f3=open(n3,'r')
soup3=BeautifulSoup(f3,'html.parser')
result1=soup3.find_all('paper')
result2=result1[1].find_all('author')

# %%
x=[]
y=[]
for i in range(0,len(result1)):
    x.append(i)
    z=len(result1[i].find_all('author'))
    y.append(z)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = x
y_pos = np.arange(len(objects))
performance = y
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Authors')
plt.title('Number of Authors per paper of EMNLP 1996')
plt.xlabel("paper number")
 
plt.show()

# %%
n4='emnlp/emnlp17.txt'
f4=open(n4,'r')
soup4=BeautifulSoup(f4,'html.parser')
result1=soup4.find_all('paper')
result2=result1[1].find_all('author')

# %%
x=[]
y=[]
for i in range(0,len(result1)):
    x.append(i)
    z=len(result1[i].find_all('author'))
    y.append(z)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = x
y_pos = np.arange(len(objects))
performance = y
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Authors')
plt.title('Number of Authors per paper of EMNLP 2017')
plt.xlabel("paper number")
 
plt.show()

# %%
n5='naacl/naacl0.txt'
f5=open(n5,'r')
soup5=BeautifulSoup(f5,'html.parser')
result1=soup5.find_all('paper')
result2=result1[1].find_all('author')

# %%
x=[]
y=[]
for i in range(0,len(result1)):
    x.append(i)
    z=len(result1[i].find_all('author'))
    y.append(z)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = x
y_pos = np.arange(len(objects))
performance = y
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Authors')
plt.title('Number of Authors per paper of NAACL 2000')
plt.xlabel("paper number")
 
plt.show()

# %%
n6='naacl/naacl18.txt'
f6=open(n6,'r')
soup6=BeautifulSoup(f6,'html.parser')
result1=soup6.find_all('paper')
result2=result1[1].find_all('author')

# %%
x=[]
y=[]
for i in range(0,len(result1)):
    x.append(i)
    z=len(result1[i].find_all('author'))
    y.append(z)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = x
y_pos = np.arange(len(objects))
performance = y
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Number of Authors')
plt.title('Number of Authors per paper of NAACL 2018')
plt.xlabel("paper number")
 
plt.show()
