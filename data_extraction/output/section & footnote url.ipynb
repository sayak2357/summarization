# %%
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import operator
import re
import glob

# %%
for i in range(79,100):
    n1 =str("output/")+str("P")+str(i)+str("*")+str("section*")
    n2 =str("output/")+str("P")+str(i)+str("*")+str("footnote*")
    for name in glob.glob(n1):
        print(name)
        t=open(name)
        for j in t:
            print(j)
# Out:
# output\P79-1001_section_names.xml
# <sec_map />
# output\P79-1002_section_names.xml
# <sec_map />
# output\P79-1003_section_names.xml
# <sec_map />
# output\P79-1004_section_names.xml
# <sec_map />
# output\P79-1005_section_names.xml
# <sec_map />
# output\P79-1006_section_names.xml
# <sec_map />
# output\P79-1007_section_names.xml
# <sec_map />
# output\P79-1008_section_names.xml
# <sec_map />
# output\P79-1009_section_names.xml
# <sec_map />
# output\P79-1010_section_names.xml
# <sec_map />
# output\P79-1011_section_names.xml
# <sec_map />
# output\P79-1012_section_names.xml
# <sec_map />
# output\P79-1013_section_names.xml
# <sec_map />
# output\P79-1014_section_names.xml
# <sec_map />
# output\P79-1015_section_names.xml
# <sec_map />
# output\P79-1016_section_names.xml
# <sec_map />
# output\P79-1017_section_names.xml
# <sec_map />
# output\P79-1018_section_names.xml
# <sec_map />
# output\P79-1019_section_names.xml
# <sec_map />
# output\P79-1020_section_names.xml
# <sec_map />
# ...
